# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/MyDrive/Yolov8
# Out:
# /content/drive/MyDrive/Yolov8

# %%
# !pip install ultralytics
#!pip install roboflow

#from IPython import display
# display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.12 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 982.1 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TqmXDNEJhiQV8XFdma4h")
project = rf.workspace("fastnuces-n0jht").project("pedestrian-detection-yfdec")
dataset = project.version(2).download("yolov8")


# from roboflow import Roboflow
# rf = Roboflow(api_key="btagijKQyOUVSL33GzHv")
# project = rf.workspace("codoid-u8ikx").project("elements-osrsw")
# dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.12, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Pedestrian-Detection-2 in yolov8:: 100%|██████████| 396/396 [00:00<00:00, 3128.91it/s]

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model

# # Predict with the model
results = model('/content/original.jpg',save=True,hide_labels=False,hide_conf=True, save_txt=True )
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_conf' instead.
#
# image 1/1 /content/original.jpg: 640x640 3 persons, 2 umbrellas, 11.5ms
# Speed: 4.8ms preprocess, 11.5ms inference, 878.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
# 1 label saved to runs/segment/predict/labels

# %%
import torch

# Load the file
pt_file = torch.load("/content/drive/MyDrive/Yolov8/runs/video_testing/best.pt")

# Print the head of the file
print(pt_file[:5])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-bc59d50b3f71> in <cell line: 4>()
#       2
#       3 # Load the file
# ----> 4 pt_file = torch.load("/content/drive/MyDrive/Yolov8/runs/video_testing/best.pt")
#       5
#       6 # Print the head of the file
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1012                     except RuntimeError as e:
#    1013                         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1014                 return _load(opened_zipfile,
#    1015                              map_location,
#    1016                              pickle_module,
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Yolov8/runs/detect/train42/weights/best.pt")

results = model.predict("/content/image2.png",save=True,save_crop=True,hide_labels=False,hide_conf=True,save_txt=True,project="/content/drive/MyDrive/Yolov8/runs/detect2")
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_conf' instead.
#
# image 1/1 /content/image2.png: 384x640 1 text, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/drive/MyDrive/Yolov8/runs/detect2/predict52
# 1 label saved to /content/drive/MyDrive/Yolov8/runs/detect2/predict52/labels

# %%
model = YOLO("/content/drive/MyDrive/Yolov8/runs/video_testing/best.pt")
results=model.predict("C:/Users/CODOID/Yolov8/test.png",save=True,save_crop=True,hide_labels=False,hide_conf=True,save_txt=True,project="C:/Users/CODOID/Yolov8/runs/detect2")

predicted_image=r"C:\Users\CODOID\Yolov8\runs\detect2"
img_list=os.listdir(predicted_image)
l1=[]
foldername=""
maxval=0
for i in img_list:
  if(re.search(r'\d+', i)!=None):
    result=int(re.search(r'\d+', i).group())
    if(int(result) > maxval):
      maxval=result
      # print(result,i)
      foldername=i

predictedfile1=os.listdir("C:/Users/CODOID/Yolov8/runs/detect2/" + foldername + "/labels/")[0]
dir=r"C:/Users/CODOID/Yolov8/runs/detect2/" + foldername + "/labels/" + predictedfile1

with open(dir) as file:
    lines = file.readlines()
l=[]
for line in lines:
    values=line.strip().split()
    value=list(map(float,values))
    l.append(value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0668dddba568> in <cell line: 1>()
# ----> 1 model = YOLO("C:/Users/CODOID/Yolov8/train29/weights/best.pt")
#       2 results=model.predict("C:/Users/CODOID/Yolov8/test.png",save=True,save_crop=True,hide_labels=False,hide_conf=True,save_txt=True,project="C:/Users/CODOID/Yolov8/runs/detect2")
#       3
#       4 predicted_image=r"C:\Users\CODOID\Yolov8\runs\detect2"
#       5 img_list=os.listdir(predicted_image)
#
# NameError: name 'YOLO' is not defined

# %%
# %cd /content/drive/MyDrive/Yolov8

# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/Yolov8/Elements_4/data.yaml epochs=500 patience=500 batch=8
# Out:
# /content/drive/MyDrive/Yolov8
# Ultralytics YOLOv8.0.232 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %cd /content/drive/MyDrive/Yolov8
# Out:
# /content/drive/MyDrive/Yolov8

# %%
# !yolo 'task=detect' 'mode=train' 'resume' 'model=/content/drive/MyDrive/Yolov8/ABB/last.pt' 'data=/content/drive/MyDrive/Yolov8/data.yaml'
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 249, in entrypoint
#     getattr(model, mode)(verbose=True, **overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 203, in train
#     self.trainer = self.TrainerClass(overrides=overrides)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py", line 84, in __init__
#     self.check_resume()
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py", line 521, in check_resume
#     assert args_yaml.is_file(), \
# AssertionError: Resume checkpoint f{last} not found. Please pass a valid checkpoint to resume from, i.e. yolo resume=path/to/last.pt
# Sentry is attempting to send 2 pending events
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/Yolov8/runs/detect/train42/weights/best.pt")
results=model.predict("/content/drive/MyDrive/Elements.v1i.yolov8/valid/images/1-2-_jpeg_jpg.rf.516d1c7fb11684be683ace95af7dd353.jpg",save=True,save_crop=True,line_thickness=1,hide_labels=True,hide_conf=True,conf=0.50,project="/content/drive/MyDrive/Yolov8/runs/detect2")
# Out:
# WARNING ⚠️ 'line_thickness' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'line_width' instead.
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_conf' instead.
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-9c62859c88af>", line 3, in <cell line: 3>
# ...

# %%
# boxes = results.boxes
# box = boxes[0]
# box.xywhn

for r in results:
    for c in r.boxes:
         b = c.xyxy[0]
         print(b)
# Out:
# tensor([1082.,  141., 1117.,  167.], device='cuda:0')
# tensor([1082.,  141., 1117.,  167.], device='cuda:0')
# tensor([1082.,  141., 1117.,  167.], device='cuda:0')

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/Yolov8/runs/detect/train29/weights/best.pt")
model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/Yolov8/runs/detect/train29/weights/best.pt with output shape (1, 5, 8400) (21.4 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 48.1 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.1...
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# ONNX: export success ✅ 9.5s, saved as /content/drive/MyDrive/Yolov8/runs/detect/train29/weights/best.onnx (42.6 MB)
#
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/Yolov8/runs/detect/train29/weights/best.pt")  # load a custom model

# Predict with the model
#results = model("/content/drive/MyDrive/Yolov8/1.jpg",save=True)
results=model.predict("/content/drive/MyDrive/Yolov8/third.png",save=True,save_crop=True,line_thickness=1,hide_labels=True,hide_conf=False,conf=0.50,project="/content/drive/MyDrive/Yolov8/runs/detect2")
# boxes = results.boxes
# box = boxes[0]
# box.xywhn

# for r in results:
#     for c in r.boxes.cls:
#         print(model.names[int(c)])
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/utils/plotting.py:160: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xyxy = torch.tensor(xyxy).view(-1, 4)
# Results saved to /content/drive/MyDrive/Yolov8/runs/detect2/predict51

# %%
for r in results:
    for c in r.boxes.cls:
        print(model.names[int(c)])
# Out:
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg
# seg

# %%
import os
import re
from os import path
predicted_image="/content/drive/MyDrive/Yolov8/runs/detect2"
img_list=os.listdir(predicted_image)
l1=[]
foldername=""
maxval=0
for i in img_list:
  if(re.search(r'\d+', i)!=None):
    result=int(re.search(r'\d+', i).group())
    if(int(result) > maxval):
      maxval=result
      # print(result,i)
      foldername=i


predictedfile1=os.listdir("/content/drive/MyDrive/Yolov8/runs/detect2/"+foldername+"/crops")
final_dir={}
for i in predictedfile1:
  source_dir=("/content/drive/MyDrive/Yolov8/runs/detect2/"+foldername+"/crops/"+i)
  image=os.listdir(source_dir)
  for j in image:
    source_image=(source_dir+"/"+j)
    # print(source_image)
    final_dir.update({i:source_image})
# Out:
# {'name': '/content/drive/MyDrive/Yolov8/runs/detect2/predict22/crops/name/pn.jpg', 'pan_no': '/content/drive/MyDrive/Yolov8/runs/detect2/predict22/crops/pan_no/pn.jpg', 'dob': '/content/drive/MyDrive/Yolov8/runs/detect2/predict22/crops/dob/pn.jpg'}

# %%
import os
import re
from os import path
predicted_image="/content/drive/MyDrive/Yolov8/runs/detect2"
img_list=os.listdir(predicted_image)
l1=[]
foldername=""
maxval=0
for i in img_list:
  if(re.search(r'\d+', i)!=None):
    result=int(re.search(r'\d+', i).group())
    if(int(result) > maxval):
      maxval=result
      # print(result,i)
      foldername=i

print(foldername)

predictedfile1=os.listdir("/content/drive/MyDrive/Yolov8/runs/detect2/"+foldername+"/crops")
final_dir={}
for i in predictedfile1:
  source_dir=("/content/drive/MyDrive/Yolov8/runs/detect2/"+foldername+"/crops/"+i)
  print(source_dir)
# Out:
# predict22
# /content/drive/MyDrive/Yolov8/runs/detect2/predict22/crops/name
# /content/drive/MyDrive/Yolov8/runs/detect2/predict22/crops/pan_no
# /content/drive/MyDrive/Yolov8/runs/detect2/predict22/crops/dob

# %%
import configparser

# Load YOLO model configuration file
config = configparser.ConfigParser()
config.read('yolo.cfg')  # Replace 'yolo.cfg' with your YOLO model configuration file

# Get width (w) and height (h) from the configuration file
width = int(config['net']['width'])
height = int(config['net']['height'])

print(f"Width (w): {width}")
print(f"Height (h): {height}")

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/yolov8_/runs/detect/train4/weights/best.pt")
results=model.predict("/content/drive/MyDrive/yolov8_/valid/images",save=True,save_txt=True,line_thickness=1,hide_labels=True,hide_conf=False,conf=0.50,project="/content/drive/MyDrive/yolov8_/runs/detect2")
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# Results saved to /content/drive/MyDrive/yolov8_/runs/detect2/predict
# 2 labels saved to /content/drive/MyDrive/yolov8_/runs/detect2/predict/labels

# %%
# %cd /content/drive/MyDrive/yolov8_

# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/yolov8_/data.yaml epochs=500  plots=Tru patience=500
# Out:
# /content/drive/MyDrive/yolov8_
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
predicted_image="/home/codoid/Downloads/Ai_Algorithms/All_AI_Models-20230220T063549Z-001/All_AI_Models/static/detect"
        img_list = os.listdir(predicted_image)
        img_list.sort()
        l1=[]
        foldername=""
        maxval=0
        for i in img_list:
            # print(re.search(r'\d+', i).group())
            if(re.search(r'\d+', i)!=None):
                result=int(re.search(r'\d+', i).group())
                if(int(result) > maxval):
                    maxval=result
                    print(result,i)
                    foldername=i

        predicted_file1=os.listdir("/home/codoid/Downloads/Ai_Algorithms/All_AI_Models-20230220T063549Z-001/All_AI_Models/static/detect/"+foldername)
        print(predicted_file1[0])
        # return render(request, {'images': img_list}, status=status.HTTP_200_OK)
        return Response({"message": "/static/detect/"+foldername+"/"+predicted_file1[0]})

# %%
a=['a','b','c']

# %%
a=['predict']

# %%
import os
txt_path = os.path.join('/output/'+a[-1]+'/lables')

# %%
txt_path
# Out:
# '/output/predict/lables'

# %%
get_txt ="/content/third - Copy (71).txt"
with open (get_txt,'r') as f:
  print(type(f.read()))
# Out:
# <class 'str'>

# %%
with open('/content/third - Copy (71).txt', 'r') as f:
    myNames = [line.strip() for line in f]

# %%
myNames
# Out:
# ['0 0.616369 0.608626 0.0580975 0.0832928']

# %%
with open("/content/third - Copy (71).txt") as f:
    lst = [float(x) for x in f.read().split()]

# %%
lst[1:]
# Out:
# [0.616369, 0.608626, 0.0580975, 0.0832928]

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.2/661.2 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# Install the ultralytics package from GitHub
# !pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
# ...
#   Cloning https://github.com/ultralytics/ultralytics.git (to revision main) to /tmp/pip-req-build-9usolq0l
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics.git /tmp/pip-req-build-9usolq0l
#   Resolved https://github.com/ultralytics/ultralytics.git to commit a5735724c54a9f5bcb239c151fefbd1337d7123d
#   Preparing metadata (setup.py) ... done
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.yaml')  # build a new model from YAML
model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n-seg.yaml').load('yolov8n.pt')  # build from YAML and transfer weights

# Train the model
results = model.train(data='coco128-seg.yaml', epochs=100, imgsz=640)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model
model = YOLO('path/to/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95(B)
metrics.box.map50  # map50(B)
metrics.box.map75  # map75(B)
metrics.box.maps   # a list contains map50-95(B) of each category
metrics.seg.map    # map50-95(M)
metrics.seg.map50  # map50(M)
metrics.seg.map75  # map75(M)
metrics.seg.maps   # a list contains map50-95(M) of each category

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model
model = YOLO('path/to/best.pt')  # load a custom model

# Predict with the model
results = model('/Screenshot_1.png')  # predict on an image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-6ac17bc7b567> in <cell line: 1>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # Load a model
#       4 model = YOLO('yolov8n-seg.pt')  # load an official model
#       5 model = YOLO('path/to/best.pt')  # load a custom model
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load an official model
model = YOLO('path/to/best.pt')  # load a custom trained model

# Export the model
model.export(format='onnx')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
